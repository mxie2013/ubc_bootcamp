# %%
def zero():
    return 0

# %%
zero()
# Out:
# 0

# %%
print  'rethurn value: ', zero()
return value: 0
# Out:
#   File "<ipython-input-5-3d6420ca0f31>", line 2
#     return value: 0
#     ^
# IndentationError: unexpected indent

# %%
import novice
def make_thumbnail(filename, width=100):
    picture = novice.open(filename) #thiis a comment
    new_height = int(picture.height * float(width)/picture.width)
    picture.size = (width, new_height)
    return picture

# %%
tn = make_thumbnail('flower.png', 200)
tn
# Out:
# Picture (format: png, path: None, modified: True)
